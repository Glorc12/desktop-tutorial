# %% [markdown]
# <a href="https://colab.research.google.com/github/Glorc12/desktop-tutorial/blob/main/CovidTeam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Описание структуры набора данных, которые употребляються в DataFrame

# %% [markdown]
# iso_code - ISO 3166-1 alpha-3 - трехбуквенные коды стран, Обратите внимание, что регионы, определенные OWID (например, континенты, такие как "Европа"), содержат префикс "OWID_".
#
# continent - Континент географического положения.
#
# location - Географическое положение.Местоположение "Международное" учитывает особые регионы (круизы "Diamond Princess" и "MS Zaandam").
#
# date - Дата наблюдения/Дата в формате yyyy-mm-dd (То есть год-месяц-день)
#
# total_cases - Общее количество подтвержденных случаев COVID-19, подсчеты могут включать вероятные случаи, о которых сообщалось.
#
# new_cases - Новые подтвержденные случаи заболевания COVID-19, Подсчеты могут включать вероятные случаи, о которых сообщалось, в редких случаях, когда наш источник сообщает об отрицательном ежедневном изменении из-за коррекции данных, мы устанавливаем для этого показателя значение NA.
#
# new_cases_smoothed - Новые подтвержденные случаи COVID-19 (7-дневный период сглажен), подсчеты могут включать вероятные случаи, о которых сообщалось.
#
# total_deaths - Общее количество смертей, связанных с COVID-19, подсчеты могут включать вероятные случаи смерти, о которых сообщалось.
#
# new_deaths - Новые случаи смерти, связанные с COVID-19, Подсчеты могут включать вероятные случаи смерти, о которых сообщалось, в редких случаях, когда наш источник сообщает об отрицательном ежедневном изменении из-за корректировки данных, мы устанавливаем для этого показателя значение NA.
#
# new_deaths_smoothed - Новые случаи смерти, связанные с COVID-19 (сглажены за 7 дней), подсчеты могут включать вероятные случаи смерти, о которых сообщалось.
#
# total_cases_per_million - Общее количество подтвержденных случаев COVID-19 на 1 000 000 человек, подсчеты могут включать вероятные случаи, о которых сообщалось.
#
# new_cases_per_million - Новые подтвержденные случаи COVID-19 на 1 000 000 человек, подсчеты могут включать вероятные случаи, о которых сообщалось.
#
# new_cases_smoothed_per_million - Новые подтвержденные случаи COVID-19 (сглаженные за 7 дней) на 1 000 000 человек, подсчеты могут включать вероятные случаи, о которых сообщалось.
#
# total_deaths_per_million - Общее число смертей, связанных с COVID-19 на 1 000 000 человек, подсчеты могут включать вероятные случаи смерти, о которых сообщалось.
#
# new_deaths_per_million - Новые случаи смерти, связанные с COVID-19, на 1 000 000 человек, подсчеты могут включать вероятные случаи смерти, о которых сообщалось.
#
# new_deaths_smoothed_per_million - Новые случаи смерти, связанные с COVID-19 (сглаженные за 7 дней) на 1 000 000 человек, подсчеты могут включать вероятные случаи смерти, о которых сообщалось.
#
# reproduction_rate - Оценка эффективной скорости размножения (R) COVID-19 в режиме реального времени.
#
# См. https://github.com/crondonm/TrackingR/tree/main/Estimates-Database
#
# icu_patients - Количество пациентов с COVID-19 в отделениях интенсивной терапии (ОИТ) за определенный день
#
# icu_patients_per_million - Количество пациентов с COVID-19 в отделениях интенсивной терапии (ОИТ) в данный день на 1 000 000 человек
#
# hosp_patients - Количество пациентов с COVID-19 в больнице в данный день
#
# hosp_patients_per_million - Количество пациентов с COVID-19 в больнице в данный день на 1 000 000 человек
#
# weekly_icu_admissions - Количество пациентов с COVID-19, вновь поступивших в отделения интенсивной терапии (ОИТ) за данную неделю (отчетная дата и предшествующие 6 дней)
#
# weekly_icu_admissions_per_million - Число пациентов с COVID-19, вновь поступивших в отделения интенсивной терапии (ОИТ) за данную неделю на 1 000 000 человек (отчетная дата и предшествующие 6 дней)
#
# weekly_hosp_admissions - Количество пациентов с COVID-19, вновь поступивших в больницы за данную неделю (отчетная дата и предшествующие 6 дней)
#
# weekly_hosp_admissions_per_million - Число пациентов с COVID-19, вновь поступивших в больницы за данную неделю на 1 000 000 человек (отчетная дата и предшествующие 6 дней)
#
# total_tests - Общее количество тестов на COVID-19 new_tests - Новые тесты на COVID-19 (рассчитываются только для последовательных дней)
#
# total_tests_per_thousand - Общее количество тестов на COVID-19 на 1000 человек new_tests_smoothed - Новые тесты на COVID-19 (сглажены за 7 дней).
#
# Для стран, которые не сообщают данные тестирования на ежедневной основе, мы предполагаем, что результаты тестирования ежедневно менялись одинаково в течение любых периодов, в которые данные не сообщались. В результате получается полный ряд ежедневных показателей, которые затем усредняются в течение 7-дневного периода
#
# new_tests_smoothed_per_thousand - Новые тесты на COVID-19 (сглаженные за 7 дней) на 1000 человек
#
# positive_rate - Доля положительных тестов на COVID-19, приведенная в виде скользящего среднего значения за 7 дней (это обратная величина tests_per_case)
#
# tests_per_case - Тесты, проводимые для каждого нового подтвержденного случая COVID-19, приведены в виде скользящего среднего значения за 7 дней (это обратная величина positive_rate)
#
# tests_units - Единицы, используемые местоположением для предоставления данных тестирования. Файл страны не может содержать смешанные единицы измерения. Все показатели, касающиеся данных тестирования, используют указанную тестовую единицу.
#
# Допустимыми единицами измерения являются "проверенные люди" (количество проверенных людей), "проведенные тесты" (количество проведенных тестов. Одного человека можно тестировать более одного раза в день) и "проверенные образцы" (количество проверенных образцов.В некоторых случаях для выполнения одного теста может потребоваться более одного образца.)
#
# total_vaccinations - Общее количество введенных доз вакцинации против COVID-19.
#
# people_vaccinated - Общее число людей, получивших хотя бы одну дозу вакцины.
#
# people_fully_vaccinated - Общее число людей, получивших все дозы, предписанные первоначальным протоколом вакцинации.
#
# total_boosters - Общее количество введенных бустерных доз вакцинации против COVID-19(дозы, введенные сверх количества, предписанного протоколом вакцинации).
#
# new_vaccinations - Вводятся новые дозы вакцинации против COVID-19 (рассчитанные только для последовательных дней).

# %% [markdown]
# # Парсинг данных

# %% [markdown]
# Добавляем ?raw=true в конце URL-адреса GitHub, чтобы получить ссылку на необработанный файл и создаём DataFrame (df) из полученных данных прочитаные с url.

# %%
url="https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-data.csv?raw=true"
df = pd.read_csv(url)

# %% [markdown]
# Проверка на количество пропущенных данных(значений).

# %%
print("Number of missing values in train dataset:")
print(df.isna().sum())
# Out:
# Number of missing values in train dataset:
# iso_code                                        0
# continent                                   12894
# location                                        0
# date                                            0
# total_cases                                  9176
#                                             ...
# human_development_index                     44992
# excess_mortality_cumulative_absolute       216794
# excess_mortality_cumulative                216794
# excess_mortality                           216744
# excess_mortality_cumulative_per_million    216794
# Length: 67, dtype: int64

# %% [markdown]
# Визуализируем пропуски в наших данных.
#
# Возможные цвета визуализации пропусков: Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'.

# %%
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(df.isnull(), cbar = False, cmap = 'Greys')
plt.show()

# %% [markdown]
# Быстрая проыверка на наличие DataFrame.

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %% [markdown]
# # Предобработка данных и выделение значимых атрибутов

# %% [markdown]
# ## Заполняем и выкидываем пустые значения по континенту

# %% [markdown]
# Общий просмотр по таблице, сколько всего пустых значений.

# %%
continent = df[df['continent'].isnull()]
continent
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 967     OWID_AFR       NaN   Africa  2020-02-13          NaN        0.0
# 968     OWID_AFR       NaN   Africa  2020-02-14          1.0        1.0
# 969     OWID_AFR       NaN   Africa  2020-02-15          1.0        0.0
# 970     OWID_AFR       NaN   Africa  2020-02-16          1.0        0.0
# 971     OWID_AFR       NaN   Africa  2020-02-17          1.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 221668  OWID_WRL       NaN    World  2022-10-13  623741751.0   631168.0
# 221669  OWID_WRL       NaN    World  2022-10-14  624194044.0   452293.0
# 221670  OWID_WRL       NaN    World  2022-10-15  624407708.0   213664.0
# 221671  OWID_WRL       NaN    World  2022-10-16  624599147.0   191439.0
# 221672  OWID_WRL       NaN    World  2022-10-17  625133156.0   534009.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# Заменяем (исправляем) пустые значение на другое значение.

# %%
# заменим всем у кого пропуски Континента и локация Africa
continent.loc[pd.isna(continent['continent'])&(continent['location'] == 'Africa'), 'continent'] = 'Africa'
# заменим всем у кого пропуски Континента и локация Asia
continent.loc[pd.isna(continent['continent'])&(continent['location'] == 'Asia'), 'continent'] = 'Asia'
# заменим всем у кого пропуски Континента и локация Europe
continent.loc[pd.isna(continent['continent'])&((continent['location'] == 'Europe')|(continent['location'] == 'European Union')), 'continent'] = 'Europe'
# заменим всем у кого пропуски Континента и локация North America
continent.loc[pd.isna(continent['continent'])&(continent['location'] == 'North America'), 'continent'] = 'North America'
# заменим всем у кого пропуски Континента и локация Oceania
continent.loc[pd.isna(continent['continent']) & (continent['location'] == 'Oceania'), 'continent'] = 'Oceania'
# заменим всем у кого пропуски Континента и локация South America
continent.loc[pd.isna(continent['continent']) & (continent['location'] == 'South America'), 'continent'] = 'South America'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# Удаляем все строки в которых локация равна одному из значений из квадратных скобок.

# %%
continent = continent.query("location not in ['High income', 'International', 'Low income', 'Lower middle income', 'Upper middle income', 'World']")

# %% [markdown]
# Провека, сколько ещё пустных  значений в DataFrame.

# %%
continent.isnull().sum()
# Out:
# iso_code                                      0
# continent                                     0
# location                                      0
# date                                          0
# total_cases                                   5
#                                            ...
# human_development_index                    6942
# excess_mortality_cumulative_absolute       6942
# excess_mortality_cumulative                6942
# excess_mortality                           6942
# excess_mortality_cumulative_per_million    6942
# Length: 67, dtype: int64

# %% [markdown]
# Удаление столбцов, в которых пустых значений насчитывается на 70 от всего столбца.

# %%
# удаляем все столбцы в которых пропусков данных больше 70%
thresh = len(continent)*0.7
df1 = continent.loc[:, continent.isna().sum().le(thresh)]

# %% [markdown]
# Проверка, сколько ещё осталось пропущенных значений.

# %%
df1.isnull().sum()
# Out:
# iso_code                                         0
# continent                                        0
# location                                         0
# date                                             0
# total_cases                                      5
# new_cases                                        0
# new_cases_smoothed                              35
# total_deaths                                   141
# new_deaths                                       0
# new_deaths_smoothed                             35
# total_cases_per_million                          5
# new_cases_per_million                            0
# new_cases_smoothed_per_million                  35
# total_deaths_per_million                       141
# new_deaths_per_million                           0
# new_deaths_smoothed_per_million                 35
# total_vaccinations                            2295
# people_vaccinated                             2295
# ...

# %% [markdown]
# Визуализируем, сколько ещё осталось пропущенных значений в DataFrame.

# %%
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(df1.isnull(), cbar = False, cmap = 'Greys')
plt.show()

# %% [markdown]
# Выводим список столбцов со значением object.

# %%
df1.columns[df1.dtypes=='object']
# Out:
# Index(['iso_code', 'continent', 'location', 'date'], dtype='object')

# %% [markdown]
# Перекодируем объекты типа object в числа.

# %%
from sklearn import preprocessing
transform = ['iso_code', 'continent', 'location', 'date']
for col in transform:
   # создание и обучение
    le = preprocessing.LabelEncoder()
    df1[col] = le.fit_transform(df1[col])
    integer_mapping = {l: i for i, l in enumerate(le.classes_)}
    print('значения полученные при переодировке ', col, '-', integer_mapping)
# Out:
# значения полученные при переодировке  iso_code - {'OWID_AFR': 0, 'OWID_ASI': 1, 'OWID_EUN': 2, 'OWID_EUR': 3, 'OWID_NAM': 4, 'OWID_OCE': 5, 'OWID_SAM': 6}
# значения полученные при переодировке  continent - {'Africa': 0, 'Asia': 1, 'Europe': 2, 'North America': 3, 'Oceania': 4, 'South America': 5}
# значения полученные при переодировке  location - {'Africa': 0, 'Asia': 1, 'Europe': 2, 'European Union': 3, 'North America': 4, 'Oceania': 5, 'South America': 6}
# ...

# %% [markdown]
# Выведем перекодированые данные.

# %%
df1
# Out:
#         iso_code  continent  location  date  total_cases  new_cases  \
# 967            0          0         0    22          NaN        0.0
# 968            0          0         0    23          1.0        1.0
# 969            0          0         0    24          1.0        0.0
# 970            0          0         0    25          1.0        0.0
# 971            0          0         0    26          1.0        0.0
# ...          ...        ...       ...   ...          ...        ...
# 187413         6          5         6   995   64095941.0    15123.0
# 187414         6          5         6   996   64108439.0    12498.0
# 187415         6          5         6   997   64113917.0     5478.0
# 187416         6          5         6   998   64120152.0     6235.0
# 187417         6          5         6   999   64124822.0     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 967                    NaN           NaN         0.0                  NaN
# ...

# %% [markdown]
# По возможности, пытаемся заполнить оставшиеся пустые значения по методу ffill.

# %%
# Из-за слабых вычислительных мощностей, приходиться пользоваться вначале заполнением по прошлым
# заполняем пропуски в данных на основе метода ffill - заполнение пропуска прошлым имеющимся
df1.fillna(method='ffill', inplace=True)
1

2

3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %% [markdown]
# Провека, сколько ещё остлось пустых значений.

# %%
df1.isna().sum()
# Out:
# iso_code                                        0
# continent                                       0
# location                                        0
# date                                            0
# total_cases                                     1
# new_cases                                       0
# new_cases_smoothed                              5
# total_deaths                                   24
# new_deaths                                      0
# new_deaths_smoothed                             5
# total_cases_per_million                         1
# new_cases_per_million                           0
# new_cases_smoothed_per_million                  5
# total_deaths_per_million                       24
# new_deaths_per_million                          0
# new_deaths_smoothed_per_million                 5
# total_vaccinations                            331
# people_vaccinated                             331
# people_fully_vaccinated                       356
# ...

# %% [markdown]
# Оставшиеся значения заменим с помощью среднего значения, т. к. оставшиеся пустые значения в общем количество по сравнению с остальными значениями мало. И их можно заменить на среднее значение, чтобы не потерять хороший потенциал обучения. машины.

# %%
# Заполним пропуски с помощью среднего значения

col_missing = ['total_cases', 'new_cases_smoothed', 'total_deaths', 'new_deaths_smoothed',
               'total_cases_per_million', 'new_cases_smoothed_per_million', 'total_deaths_per_million',
               'new_deaths_smoothed_per_million', 'total_vaccinations', 'people_vaccinated',
               'people_fully_vaccinated', 'total_boosters', 'new_vaccinations',
               'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
               'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
               'total_boosters_per_hundred', 'new_vaccinations_smoothed_per_million',
               'new_people_vaccinated_smoothed', 'new_people_vaccinated_smoothed_per_hundred']

for i in col_missing:
    df1[i].fillna(df1[i].mean(), inplace=True)

df1.isna().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# iso_code                                      0
# continent                                     0
# location                                      0
# date                                          0
# total_cases                                   0
# new_cases                                     0
# new_cases_smoothed                            0
# total_deaths                                  0
# new_deaths                                    0
# new_deaths_smoothed                           0
# total_cases_per_million                       0
# new_cases_per_million                         0
# new_cases_smoothed_per_million                0
# ...

# %% [markdown]
# Проверка типов данных в DataFrame.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6942 entries, 967 to 187417
# Data columns (total 30 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    6942 non-null   int64
#  1   continent                                   6942 non-null   int64
#  2   location                                    6942 non-null   int64
#  3   date                                        6942 non-null   int64
#  4   total_cases                                 6942 non-null   float64
#  5   new_cases                                   6942 non-null   float64
#  6   new_cases_smoothed                          6942 non-null   float64
#  7   total_deaths                                6942 non-null   float64
#  8   new_deaths                                  6942 non-null   float64
# ...

# %% [markdown]
# ## Работа с выбросами

# %% [markdown]
# - медиана (Q2/50-й процентиль): среднее значение набора данных.
# - первый квартиль (Q1/25-й процентиль): среднее число между
# - наименьшим числом (не «минимум») и медианой набора данных.
# - третий квартиль (Q3/75-й процентиль): среднее значение между
# - медианой и максимальным значением (не «максимальным») набора данных.
# - Межквартильный диапазон (IQR) : от 25-го до 75-го процентиля. IQR показывает, насколько разбросаны средние значения.
# - «максимум»: Q3 + 1,5*IQR
# - «минимум»: Q1 -1,5*IQR
# - Выбросы : Все что не входит в промежуток Q1-Q3 будет у нас выбросом

# %%
# plt.figure(figsize=(5,5))

# df1[['Depth', 'Thickness (gross average ft)', 'Thickness (net pay average ft)', 'Porosity', 'Permeability']].plot(kind='box')
# _, bp = train.Depth.plot.box(return_type='both', figsize=(6,6))

# %%
# Выбросы присутствуют в total_cases, new_cases, new_cases_smoothed, new_deaths, new_deaths_smoothed, total_cases_per_million, new_cases_per_million, new_cases_smoothed_per_million, new_deaths_per_million,
# new_deaths_smoothed_per_million, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population

# %% [markdown]
# ### Дальше идёт удаление выбрасов
# Т. к. для каждого столбца нужно новый блок и проверка, решено было сделать в закрывающуюся вкладку. Так же все действия однотипны для каждого столбца, но с разными водными данными в формуле (например, Q1 и Q3 и IQR).

# %% [markdown]
# #### Работа с таблицей total_cases

# %%
# выбросы для iso_code, continent, location, date, total_deaths, total_deaths_per_million, total_vaccinations_per_hundred, people_vaccinated_per_hundred, people_fully_vaccinated_per_hundred, total_boosters_per_hundred отсутствуют
Q1 =  df1.total_cases.quantile(0.25)
Q3 = df1.total_cases.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df1[(df1.total_cases < Q1-1.5*IQR ) | (df1.total_cases > Q3+1.5*IQR)]
# Out:
# 1905419.25
# 53937458.0
# 55842877.25
#        iso_code  continent  location  date  total_cases  new_cases  \
# 11414         1          1         1   794  137145213.0   625966.0
# 11415         1          1         1   795  137571910.0   426697.0
# 11416         1          1         1   796  138319764.0   747854.0
# 11417         1          1         1   797  139015974.0   696210.0
# 11418         1          1         1   798  139580996.0   565022.0
# ...         ...        ...       ...   ...          ...        ...
# 66682         2          2         3   995  170956841.0   278459.0
# 66683         2          2         3   996  171207986.0   251145.0
# 66684         2          2         3   997  171265187.0    57201.0
# 66685         2          2         3   998  171307050.0    41863.0
# 66686         2          2         3   999  171601941.0   294891.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_test = df1.loc[~((df1.total_cases < Q1-1.5*IQR ) | (df1.total_cases > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_cases

# %%
Q1 =  df_test.new_cases.quantile(0.25)
Q3 = df_test.new_cases.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_cases < Q1-1.5*IQR ) | (df_test.new_cases > Q3+1.5*IQR)]
# Out:
# 8201.5
# 99562.0
# 107763.5
#         iso_code  continent  location  date  total_cases  new_cases  \
# 11061          1          1         1   441   30082073.0   268500.0
# 11062          1          1         1   442   30361840.0   279767.0
# 11063          1          1         1   443   30655052.0   293212.0
# 11064          1          1         1   444   30944627.0   289575.0
# 11065          1          1         1   445   31250600.0   305973.0
# ...          ...        ...       ...   ...          ...        ...
# 187162         6          5         6   744   50020183.0   354887.0
# 187163         6          5         6   745   50297275.0   277092.0
# 187166         6          5         6   748   50877922.0   271119.0
# 187167         6          5         6   749   51157840.0   279918.0
# 187168         6          5         6   750   51431940.0   274100.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_cases < Q1-1.5*IQR ) | (df_test.new_cases > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_cases_smoothed

# %%
Q1 =  df_test.new_cases_smoothed.quantile(0.25)
Q3 = df_test.new_cases_smoothed.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_cases_smoothed < Q1-1.5*IQR ) | (df_test.new_cases_smoothed > Q3+1.5*IQR)]
# Out:
# 7370.857
# 81599.286
# 88970.143
#         iso_code  continent  location  date  total_cases  new_cases  \
# 11060          1          1         1   440   29813573.0   246446.0
# 11113          1          1         1   493   50843604.0   241087.0
# 11114          1          1         1   494   51071331.0   227727.0
# 11115          1          1         1   495   51274842.0   203511.0
# 11116          1          1         1   496   51481216.0   206374.0
# ...          ...        ...       ...   ...          ...        ...
# 187165         6          5         6   747   50606803.0   160105.0
# 187169         6          5         6   751   51684725.0   252785.0
# 187170         6          5         6   752   51895773.0   211048.0
# 187171         6          5         6   753   52025483.0   129710.0
# 187172         6          5         6   754   52164118.0   138635.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_cases_smoothed < Q1-1.5*IQR ) | (df_test.new_cases_smoothed > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_deaths

# %%
# Выбросы присутствуют  new_deaths, new_deaths_smoothed, total_cases_per_million, new_cases_per_million, new_cases_smoothed_per_million, new_deaths_per_million,
# new_deaths_smoothed_per_million, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_deaths.quantile(0.25)
Q3 = df_test.new_deaths.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_deaths < Q1-1.5*IQR ) | (df_test.new_deaths > Q3+1.5*IQR)]
# Out:
# 60.0
# 1418.75
# 1478.75
#         iso_code  continent  location  date  total_cases  new_cases  \
# 11120          1          1         1   500   52280615.0   181830.0
# 11121          1          1         1   501   52445649.0   165034.0
# 11126          1          1         1   506   53245226.0   158488.0
# 11127          1          1         1   507   53392095.0   146869.0
# 11128          1          1         1   508   53531684.0   139589.0
# ...          ...        ...       ...   ...          ...        ...
# 186936         6          5         6   518   32046875.0   148567.0
# 186937         6          5         6   519   32196435.0   149560.0
# 186938         6          5         6   520   32350653.0   154218.0
# 186943         6          5         6   525   32894941.0   112050.0
# 186944         6          5         6   526   33020972.0   126031.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_deaths < Q1-1.5*IQR ) | (df_test.new_deaths > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_deaths_smoothed

# %%
# Выбросы присутствуют total_cases_per_million, new_cases_per_million, new_cases_smoothed_per_million, new_deaths_per_million,
# new_deaths_smoothed_per_million, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_deaths_smoothed.quantile(0.25)
Q3 = df_test.new_deaths_smoothed.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_deaths_smoothed < Q1-1.5*IQR ) | (df_test.new_deaths_smoothed > Q3+1.5*IQR)]
# Out:
# 54.03575
# 1324.74975
# 1378.7855
#         iso_code  continent  location  date  total_cases  new_cases  \
# 11122          1          1         1   502   52593813.0   148164.0
# 11123          1          1         1   503   52754403.0   160590.0
# 11124          1          1         1   504   52921258.0   166855.0
# 11125          1          1         1   505   53086738.0   165480.0
# 11131          1          1         1   511   53935897.0   139850.0
# ...          ...        ...       ...   ...          ...        ...
# 186933         6          5         6   515   31620953.0    98394.0
# 186934         6          5         6   516   31712731.0    91778.0
# 186939         6          5         6   521   32475867.0   125214.0
# 186940         6          5         6   522   32565552.0    89685.0
# 186941         6          5         6   523   32656218.0    90666.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_deaths_smoothed < Q1-1.5*IQR ) | (df_test.new_deaths_smoothed > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей total_cases_per_million

# %%
# Выбросы присутствуют , new_cases_per_million, new_cases_smoothed_per_million, new_deaths_per_million,
# new_deaths_smoothed_per_million, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.total_cases_per_million.quantile(0.25)
Q3 = df_test.total_cases_per_million.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.total_cases_per_million < Q1-1.5*IQR ) | (df_test.total_cases_per_million > Q3+1.5*IQR)]
# Out:
# 1531.108
# 69663.925
# 71195.033
#         iso_code  continent  location  date  total_cases  new_cases  \
# 148420         4          3         4   899  104771822.0   101697.0
# 148421         4          3         4   900  104809619.0    37797.0
# 148422         4          3         4   901  105022982.0   213363.0
# 148423         4          3         4   902  105226687.0   203705.0
# 148424         4          3         4   903  105483282.0   256595.0
# ...          ...        ...       ...   ...          ...        ...
# 153258         5          4         5   996   12497823.0     1051.0
# 153259         5          4         5   997   12498444.0      621.0
# 153260         5          4         5   998   12513532.0    15088.0
# 153261         5          4         5   999   12514684.0     1152.0
# 186449         6          5         6    31   12514684.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.total_cases_per_million < Q1-1.5*IQR ) | (df_test.total_cases_per_million > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_cases_per_million

# %%
# Выбросы присутствуют , , new_cases_smoothed_per_million, new_deaths_per_million,
# new_deaths_smoothed_per_million, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_cases_per_million.quantile(0.25)
Q3 = df_test.new_cases_per_million.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_cases_per_million < Q1-1.5*IQR ) | (df_test.new_cases_per_million > Q3+1.5*IQR)]
# Out:
# 6.5865
# 106.84549999999999
# 113.43199999999999
#         iso_code  continent  location  date  total_cases  new_cases  \
# 64962          3          2         2   274    7765338.0   221151.0
# 64963          3          2         2   275    7996367.0   231029.0
# 64964          3          2         2   276    8207285.0   210918.0
# 65109          3          2         2   421   37472600.0   222601.0
# 65110          3          2         2   422   37691839.0   219239.0
# ...          ...        ...       ...   ...          ...        ...
# 187183         6          5         6   765   53970057.0   141301.0
# 187298         6          5         6   880   58821779.0   160422.0
# 187305         6          5         6   887   59345814.0   122040.0
# 187308         6          5         6   890   59643723.0   189190.0
# 187323         6          5         6   905   60975598.0   158684.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_cases_per_million < Q1-1.5*IQR ) | (df_test.new_cases_per_million > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_cases_smoothed_per_million

# %%
# Выбросы присутствуют , , , new_deaths_per_million,
# new_deaths_smoothed_per_million, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_cases_smoothed_per_million.quantile(0.25)
Q3 = df_test.new_cases_smoothed_per_million.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_cases_smoothed_per_million < Q1-1.5*IQR ) | (df_test.new_cases_smoothed_per_million > Q3+1.5*IQR)]
# Out:
# 5.926
# 91.5945
# 97.5205
#         iso_code  continent  location  date  total_cases  new_cases  \
# 64965          3          2         2   277    8362839.0   155554.0
# 65111          3          2         2   423   37888591.0   196752.0
# 65112          3          2         2   424   38065630.0   177039.0
# 65113          3          2         2   425   38217999.0   154583.0
# 65128          3          2         2   440   41203000.0   131885.0
# ...          ...        ...       ...   ...          ...        ...
# 187179         6          5         6   761   53339296.0    99229.0
# 187184         6          5         6   766   54085581.0   115524.0
# 187185         6          5         6   767   54152590.0    67009.0
# 187186         6          5         6   768   54201398.0    48808.0
# 187187         6          5         6   769   54232897.0    31499.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_cases_smoothed_per_million < Q1-1.5*IQR ) | (df_test.new_cases_smoothed_per_million > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_deaths_per_million

# %%
# Выбросы присутствуют , , , ,
# new_deaths_smoothed_per_million, total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_deaths_per_million.quantile(0.25)
Q3 = df_test.new_deaths_per_million.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_deaths_per_million < Q1-1.5*IQR ) | (df_test.new_deaths_per_million > Q3+1.5*IQR)]
# Out:
# 0.109
# 1.31025
# 1.41925
#         iso_code  continent  location  date  total_cases  new_cases  \
# 64753          3          2         2    65     320014.0    34764.0
# 64754          3          2         2    66     356514.0    36500.0
# 64755          3          2         2    67     386256.0    29742.0
# 64756          3          2         2    68     418447.0    32191.0
# 64782          3          2         2    94    1238749.0    25305.0
# ...          ...        ...       ...   ...          ...        ...
# 186986         6          5         6   568   36151116.0    59252.0
# 186987         6          5         6   569   36202142.0    51026.0
# 186991         6          5         6   573   36352825.0    55331.0
# 186992         6          5         6   574   36411035.0    58210.0
# 186993         6          5         6   575   36465733.0    54698.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_deaths_per_million < Q1-1.5*IQR ) | (df_test.new_deaths_per_million > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_deaths_smoothed_per_million

# %%
# Выбросы присутствуют , , , ,
# , total_vaccinations, people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_deaths_smoothed_per_million.quantile(0.25)
Q3 = df_test.new_deaths_smoothed_per_million.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_deaths_smoothed_per_million < Q1-1.5*IQR ) | (df_test.new_deaths_smoothed_per_million > Q3+1.5*IQR)]
# Out:
# 0.077
# 0.8585
# 0.9355
#         iso_code  continent  location  date  total_cases  new_cases  \
# 64752          3          2         2    64     285250.0    33719.0
# 64783          3          2         2    95    1260986.0    22237.0
# 64787          3          2         2    99    1353622.0    23086.0
# 64788          3          2         2   100    1377019.0    23397.0
# 64789          3          2         2   101    1399109.0    22251.0
# ...          ...        ...       ...   ...          ...        ...
# 187008         6          5         6   590   37002808.0    32255.0
# 187009         6          5         6   591   37031953.0    29145.0
# 187010         6          5         6   592   37050876.0    18923.0
# 187011         6          5         6   593   37068272.0    17396.0
# 187188         6          5         6   770   54318075.0    85178.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_deaths_smoothed_per_million < Q1-1.5*IQR ) | (df_test.new_deaths_smoothed_per_million > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей total_vaccinations

# %%
# Выбросы присутствуют , , , ,
# , , people_vaccinated, people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.total_vaccinations.quantile(0.25)
Q3 = df_test.total_vaccinations.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.total_vaccinations < Q1-1.5*IQR ) | (df_test.total_vaccinations > Q3+1.5*IQR)]
# Out:
# 314588512.25
# 772060686.75
# 1086649199.0
#        iso_code  continent  location  date  total_cases  new_cases  \
# 11160         1          1         1   540   58416735.0   221004.0
# 11161         1          1         1   541   58627144.0   210409.0
# 11162         1          1         1   542   58828647.0   201503.0
# 11163         1          1         1   543   59021424.0   192777.0
# 11164         1          1         1   544   59202277.0   180853.0
# ...         ...        ...       ...   ...          ...        ...
# 64957         3          2         2   269    6894072.0   147009.0
# 64958         3          2         2   270    7027913.0   133841.0
# 64959         3          2         2   271    7189000.0   161087.0
# 64960         3          2         2   272    7348359.0   159359.0
# 64961         3          2         2   273    7544187.0   195828.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_test = df_test.loc[~((df_test.total_vaccinations < Q1-1.5*IQR ) | (df_test.total_vaccinations > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей people_vaccinated

# %%
# Выбросы присутствуют , , , ,
# , , , people_fully_vaccinated, total_boosters, new_vaccinations, new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.people_vaccinated.quantile(0.25)
Q3 = df_test.people_vaccinated.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.people_vaccinated < Q1-1.5*IQR ) | (df_test.people_vaccinated > Q3+1.5*IQR)]
# Out:
# 156465223.75
# 294536241.25
# 451001465.0
#        iso_code  continent  location  date  total_cases  new_cases  \
# 11135         1          1         1   515   54474577.0   130772.0
# 11136         1          1         1   516   54593675.0   119098.0
# 11137         1          1         1   517   54727109.0   133434.0
# 11138         1          1         1   518   54863998.0   136889.0
# 11139         1          1         1   519   55006941.0   142943.0
# 11140         1          1         1   520   55142714.0   135773.0
# 11141         1          1         1   521   55273557.0   130843.0
# 11142         1          1         1   522   55410429.0   136872.0
# 11143         1          1         1   523   55541211.0   130782.0
# 11144         1          1         1   524   55682612.0   141401.0
# 11145         1          1         1   525   55831805.0   149193.0
# 11146         1          1         1   526   55986857.0   155052.0
# ...

# %%
df_test = df_test.loc[~((df_test.people_vaccinated < Q1-1.5*IQR ) | (df_test.people_vaccinated > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_vaccinations

# %%
# Выбросы присутствуют , , , ,
# , , , , , , new_vaccinations_smoothed, new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_vaccinations.quantile(0.25)
Q3 = df_test.new_vaccinations.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_vaccinations < Q1-1.5*IQR ) | (df_test.new_vaccinations > Q3+1.5*IQR)]
# Out:
# 182110.0
# 1585056.75
# 1767166.75
#         iso_code  continent  location  date  total_cases  new_cases  \
# 1826           0          0         0   881   11994315.0    11549.0
# 1827           0          0         0   882   12002174.0     7859.0
# 1828           0          0         0   883   12011490.0     9316.0
# 1829           0          0         0   884   12017973.0     6483.0
# 1830           0          0         0   885   12023592.0     5619.0
# ...          ...        ...       ...   ...          ...        ...
# 66220          2          2         3   533   33291998.0    41677.0
# 66227          2          2         3   540   33644537.0    67666.0
# 147961         4          3         4   440   35747737.0    87347.0
# 147976         4          3         4   455   37036601.0    83297.0
# 147977         4          3         4   456   37124225.0    87624.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_vaccinations < Q1-1.5*IQR ) | (df_test.new_vaccinations > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_vaccinations_smoothed

# %%
# Выбросы присутствуют , , , ,
# , , , , , , , new_vaccinations_smoothed_per_million,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_vaccinations_smoothed.quantile(0.25)
Q3 = df_test.new_vaccinations_smoothed.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_vaccinations_smoothed < Q1-1.5*IQR ) | (df_test.new_vaccinations_smoothed > Q3+1.5*IQR)]
# Out:
# 267987.0
# 1442751.0
# 1710738.0
#         iso_code  continent  location  date  total_cases  new_cases  \
# 65176          3          2         2   488   46835216.0    41656.0
# 65177          3          2         2   489   46885812.0    50596.0
# 65181          3          2         2   493   47126119.0    50581.0
# 65182          3          2         2   494   47166938.0    40819.0
# 65183          3          2         2   495   47204871.0    37933.0
# 65188          3          2         2   500   47449058.0    38092.0
# 65189          3          2         2   501   47482240.0    33182.0
# 65195          3          2         2   507   47743098.0    37196.0
# 65196          3          2         2   508   47777356.0    34258.0
# 65197          3          2         2   509   47815357.0    38001.0
# 65202          3          2         2   514   48020928.0    39686.0
# 65203          3          2         2   515   48056038.0    35110.0
# ...

# %%
df_test = df_test.loc[~((df_test.new_vaccinations_smoothed < Q1-1.5*IQR ) | (df_test.new_vaccinations_smoothed > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_vaccinations_smoothed_per_million

# %%
# Выбросы присутствуют , , , ,
# , , , , , , , ,
# new_people_vaccinated_smoothed, new_people_vaccinated_smoothed_per_hundred, population
Q1 =  df_test.new_vaccinations_smoothed_per_million.quantile(0.25)
Q3 = df_test.new_vaccinations_smoothed_per_million.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_vaccinations_smoothed_per_million < Q1-1.5*IQR ) | (df_test.new_vaccinations_smoothed_per_million > Q3+1.5*IQR)]
# Out:
# 424.0
# 1453.3286945999093
# 1877.3286945999093
#         iso_code  continent  location  date  total_cases  new_cases  \
# 65243          3          2         2   555   52021938.0   132653.0
# 65244          3          2         2   556   52120671.0    98733.0
# 65245          3          2         2   557   52208162.0    87491.0
# 65246          3          2         2   558   52341148.0   132986.0
# 65247          3          2         2   559   52457999.0   116851.0
# ...          ...        ...       ...   ...          ...        ...
# 187115         6          5         6   697   39273962.0    11774.0
# 187116         6          5         6   698   39285940.0    11978.0
# 187117         6          5         6   699   39310270.0    24330.0
# 187118         6          5         6   700   39330859.0    20589.0
# 187119         6          5         6   701   39358082.0    27223.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_vaccinations_smoothed_per_million < Q1-1.5*IQR ) | (df_test.new_vaccinations_smoothed_per_million > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей new_people_vaccinated_smoothed_per_hundred

# %%
# Выбросы присутствуют , , , ,
# , , , , , , , ,
# , , population
Q1 =  df_test.new_people_vaccinated_smoothed_per_hundred.quantile(0.25)
Q3 = df_test.new_people_vaccinated_smoothed_per_hundred.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.new_people_vaccinated_smoothed_per_hundred < Q1-1.5*IQR ) | (df_test.new_people_vaccinated_smoothed_per_hundred > Q3+1.5*IQR)]
# Out:
# 0.008
# 0.062000000000000006
# 0.07
#         iso_code  continent  location  date  total_cases  new_cases  \
# 148013         4          3         4   492   38993402.0    36986.0
# 148014         4          3         4   493   39016629.0    23227.0
# 148015         4          3         4   494   39031069.0    14440.0
# 148016         4          3         4   495   39050350.0    19281.0
# 148017         4          3         4   496   39088160.0    37810.0
# ...          ...        ...       ...   ...          ...        ...
# 152803         5          4         5   541      86908.0     1577.0
# 152804         5          4         5   542      88227.0     1319.0
# 152805         5          4         5   543      89390.0     1163.0
# 152806         5          4         5   544      90452.0     1062.0
# 152807         5          4         5   545      91742.0     1290.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df_test = df_test.loc[~((df_test.new_people_vaccinated_smoothed_per_hundred < Q1-1.5*IQR ) | (df_test.new_people_vaccinated_smoothed_per_hundred > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# #### Работа с таблицей population

# %%
# Выбросы присутствуют , , , ,
# , , , , , , , ,
# , ,
Q1 =  df_test.population.quantile(0.25)
Q3 = df_test.population.quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(IQR)
print(Q3)

df_test[(df_test.population < Q1-1.5*IQR ) | (df_test.population > Q3+1.5*IQR)]
# Out:
# 433956670.0
# 958437633.0
# 1392394303.0
#        iso_code  continent  location  date  total_cases  new_cases  \
# 10620         1          1         1     0        556.0        0.0
# 10621         1          1         1     1        654.0       98.0
# 10622         1          1         1     2        937.0      283.0
# 10623         1          1         1     3       1429.0      492.0
# 10624         1          1         1     4       2105.0      676.0
# ...         ...        ...       ...   ...          ...        ...
# 11033         1          1         1   413   25826828.0    89908.0
# 11034         1          1         1   414   25918599.0    91771.0
# 11035         1          1         1   415   26012359.0    93760.0
# 11036         1          1         1   416   26101021.0    88662.0
# 11037         1          1         1   417   26191748.0    90727.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_test = df_test.loc[~((df_test.population < Q1-1.5*IQR ) | (df_test.population > Q3+1.5*IQR)),:]

# %% [markdown]
# Проверка DataFrame(df1) через dt_test на удаление выбросов.

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# # Формирование дополнительного атрибута (Rt (коэффициента распространения инфекции) )

# %% [markdown]
# коэффициента распространения инфекции расчитываеться по формуле Rt = (X8+X7+X6+X5) / (X1+X2+X3+X4), где:
#
# Rt - коэффициент распространения коронавируса;
#
# X1…X8 - количество зарегистрированных больных коронавирусом в регионе за соответствующие сутки.
#
# (это формула была использована Роспотребнадзора)
#
# Создадим алгоритм для выщитывания X!...X8 и Rt.

# %%
from numpy.ma.core import append
df_total_cases = df_test['total_cases'].tolist() # список, сколько в данный день заражённых
Rt = [0,0,0,0,0,0,0,0] # коэффициент распространения коронавируса

for counter in range(len(df_total_cases[8:])): # цикл, для нахождения значений Rt
  X1 = df_total_cases[counter]
  X2 = df_total_cases[counter+1]
  X3 = df_total_cases[counter+2]
  X4 = df_total_cases[counter+3]
  X5 = df_total_cases[counter+4]
  X6 = df_total_cases[counter+5]
  X7 = df_total_cases[counter+6]
  X8 = df_total_cases[counter+7]
  Rt.append((X8+X7+X6+X5) / (X1+X2+X3+X4)) # нахождение 1 из значений будущего столбца Rt
df_test['Rt'] = Rt # добавления списка Rt в столбец 'Rt' в конце DataFrame(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# Проверка на наличие Rt в df.
#
# Нельзя забывать что первые 8 значений в df имеют 0, потому до них нету 8 дней и для них нельзя составить Rt (это один из минусов формулы Rt).

# %%
df_test
# Out:
#         iso_code  continent  location  date   total_cases  new_cases  \
# 967            0          0         0    22  3.975428e+07        0.0
# 968            0          0         0    23  1.000000e+00        1.0
# 969            0          0         0    24  1.000000e+00        0.0
# 970            0          0         0    25  1.000000e+00        0.0
# 971            0          0         0    26  1.000000e+00        0.0
# ...          ...        ...       ...   ...           ...        ...
# 187413         6          5         6   995  6.409594e+07    15123.0
# 187414         6          5         6   996  6.410844e+07    12498.0
# 187415         6          5         6   997  6.411392e+07     5478.0
# 187416         6          5         6   998  6.412015e+07     6235.0
# 187417         6          5         6   999  6.412482e+07     4670.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# # Статистику распределения данных (плотность, наличие пустых значений)

# %% [markdown]
# Статистику распределения данных с наличием пустых значений уже была начата в "gарсинге данных" и закончена в "Заполняем и выкидываем пустые значения по континенту".

# %% [markdown]
# ## Статистику распределения данных по плотности

# %% [markdown]
# Создадим список главных столбцов из DataFrame(df_test) те столбцы, которые по важности лучше остальных столбцов или являются наглядным примером для остальных столбцов.

# %%
True_list = ['iso_code', 'total_cases', 'total_deaths', 'total_cases_per_million',
'total_deaths_per_million', 'total_vaccinations']

# %% [markdown]
# Изучаем данные для диаграмм.

# %%
for name in True_list:
  print(df_test[name].value_counts())
# Out:
# 0    972
# 5    531
# 6    309
# 2    279
# 4    267
# 3     28
# Name: iso_code, dtype: int64
# 15.0          22
# 1.0           11
# 24.0           7
# 37.0           6
# 2.0            6
#               ..
# 11494578.0     1
# 11492653.0     1
# 11490082.0     1
# 11475504.0     1
# 64124822.0     1
# Name: total_cases, Length: 2287, dtype: int64
# 1.519787e+06    35
# 1.154811e+06    33
# 6.103860e+05    24
# 1.250000e+02    24
# 1.951855e+06    18
#                 ..
# 2.286360e+05     1
# 2.284530e+05     1
# 2.282120e+05     1
# 2.279110e+05     1
# 1.330992e+06     1
# Name: total_deaths, Length: 1988, dtype: int64
# 0.337         21
# 0.001         14
# 0.083          6
# 0.039          6
# 0.054          4
#               ..
# 8305.224       1
# 8302.228       1
# 8301.921       1
# 8301.481       1
# 147767.799     1
# Name: total_cases_per_million, Length: 2304, dtype: int64
# 2548.63000    35
# 2580.04400    33
# 930.67115     24
# 2.81000       24
# 2607.14800    18
# ...

# %% [markdown]
# ### Дальше будет идти цикл с созданием диаграмм, то есть создание диаграмм для столбцов, т. к. из-за этого будит очень длинная страница, решено сделать отдельную вкладку для них.

# %% [markdown]
# #### iso_code - Трёхбуквенные коды стран

# %% [markdown]
# По диаграммам видно какие страны, то есть трёхбуквенно закодированые страны, больше всего контактируют с Короновирусом.

# %%
df_test_iso_code = pd.DataFrame({'Name': ['OWID_AFR=0', 'OWID_EUN=2', 'OWID_EUR=3', 'OWID_NAM=4', 'OWID_OCE=5', 'OWID_SAM=6'],
                            'votes_of_each_class': [970, 531, 308, 279, 267, 28]})
print([df_test_iso_code.groupby(['Name']).sum().plot(kind='pie', y='votes_of_each_class')])

# %% [markdown]
# #### total_cases - Общее количество подтвержденных случаев COVID-19, подсчеты могут включать вероятные случаи, о которых сообщалось.

# %% [markdown]
# Т. к. мы знаем, что мы избавлялись от большинства выбросов. "2020-02-13": 22. Это является началом диаграмм. X- это индексы самих значений Totalcases, а Y- это их значения от 0 до 1 (после нормализации данных) по графику видно, что в начале даты 2020-02-13 уже было достаточно, но самым пиком было её индексе 150000. Тогда было подтвержденных случаев аж на 200000. Потом был спад и опять повышение по Y. (скорее всего, это вызвано мутацией коронавируса, вследствие чего появлялось много подтверждённых случаев).

# %%
plt.plot(df_test.index, df_test['total_cases'])

# %% [markdown]
# #### total_deaths - Общее количество смертей, связанных с COVID-19, подсчеты могут включать вероятные случаи смерти, о которых сообщалось.

# %% [markdown]
# Этот график практически тот же самый, что и прошлый, но за места значений Totalcases в Y были поставлены значения Totaldeaths, и по ним видно, как данные по Totaldeaths прогрессировали вместе с данными из Totalcases. Но есть маленькая деталь на индексе 50000-75000 и это внезапный рост был связан с тем, что тогда было достаточно заболевших, но они не вакцинировались и не обезопасили себя. Например, на индексе 150000 было очень много подтверждённых случаев, но т. к. люди привыкли к коронавирусу и знают о технике безопасности, против неё было меньше случаев смертей. Так же тут есть такая вещь, что до вспышки около 50000-75000 они были прямо корреляция, а после противоположно корреляция.

# %%
plt.plot(df_test.index, df_test['total_deaths'])

# %% [markdown]
# #### total_cases_per_million - Общее количество подтвержденных случаев COVID-19 на 1 000 000 человек, подсчеты могут включать вероятные случаи, о которых сообщалось.

# %% [markdown]
# Этот график практически тот же самый, что и прошлый, но за места значений Totalcases в Y были поставлены значения total_cases_per_million и по ним видно, как данные по total_cases_per_million прогрессировали вместе с данными из Totalcases. Но есть маленькая деталь на индексе 50000 - 75000, после того как резка упал и возросли значения, они были выше чем на диаграмме Totalcases связи с тем что подтверждённых случаев на миллион стало больше чем единичных случаев.

# %%
plt.plot(df_test.index, df_test['total_cases_per_million'])

# %% [markdown]
# #### total_deaths_per_million - Общее число смертей, связанных с COVID-19 на 1 000 000 человек, подсчеты могут включать вероятные случаи смерти, о которых сообщалось.

# %% [markdown]
# Этот график практически тот же самый, что и прошлый, но за места значений Totalcases в Y были поставлены значения total_cases_per_million и по ним видно, как данные по total_cases_per_million прогрессировали вместе с данными из Totalcases. Так же тут есть такая вещь, что до вспышки около 50000-75000 они были прямо корреляция, а после противоположно корреляция.

# %%
plt.plot(df_test.index, df_test['total_deaths_per_million'])

# %% [markdown]
# #### total_vaccinations - Общее количество введенных доз вакцинации против COVID-19.

# %% [markdown]
# Этот график практически тот же самый, что и прошлый, но за места значений Totalcases в Y были поставлены значения totalvaccinations, и по ним видно, как данные по totalvaccinations прогрессировали вместе с данными из Totalcases. Данные по Оси Y были нормализованы, как и прошлые с Totalcases. Так же тут есть такая вещь, что после вспышки в 0 индексе (Ось X) данные не были слишком сильно изменен. Это связано с тем, что люди пытались всё время вводить дозы вакцин для того, чтобы остановить вирус. А после индекса 50000-75000 данные Totalcases и totalvaccinations стали противоположно. корреляция (только в спешках они были на одном уровне, т. к. во время вспышки были увеличение заражённые, следовательно, и сами дозы вакцин).

# %%
plt.plot(df_test.index, df_test['total_vaccinations'])

# %% [markdown]
# # Кластеризация

# %% [markdown]
# ### KMeans Cluster

# %%
# %%time
from sklearn.cluster import KMeans

n_clusters = 6

clusterer = KMeans(n_clusters=n_clusters)

cluster_labels = clusterer.fit_predict(df_test)

# inertia
inertia = clusterer.inertia_
# Out:
# CPU times: user 287 ms, sys: 114 ms, total: 401 ms
# Wall time: 352 ms

# %%
print("For n_clusters =", n_clusters,
      ", the inertia is :", inertia)
# Out:
# For n_clusters = 6 , the inertia is : 9.2632930050632e+19

# %%
# Выводим предсказания
predictions = pd.DataFrame(cluster_labels, columns=['danger level for tourists'])
predictions = predictions.reset_index()
predictions
# Out:
#       index  danger level for tourists
# 0         0                          4
# 1         1                          4
# 2         2                          4
# 3         3                          4
# 4         4                          4
# ...     ...                        ...
# 2381   2381                          3
# 2382   2382                          3
# 2383   2383                          3
# 2384   2384                          3
# 2385   2385                          3
#
# [2386 rows x 2 columns]

# %%
a = list(predictions['danger level for tourists'].unique())
a
# Out:
# [4, 5, 2, 3, 1, 0]

# %% [markdown]
# ### GaussianMixture

# %%
# %%time
from sklearn.mixture import GaussianMixture
n_clusters = 6
gmm_model = GaussianMixture(n_components=n_clusters)
cluster_labels = gmm_model.fit_predict(df_test)
# inertia
inertia = clusterer.inertia_
# Out:
# CPU times: user 143 ms, sys: 88.2 ms, total: 231 ms
# Wall time: 304 ms

# %%
print("For n_clusters =", n_clusters,
      ", the inertia is :", inertia)
# Выводим предсказания
predictions = pd.DataFrame(cluster_labels, columns=['danger level for tourists'])
predictions = predictions.reset_index()
predictions
# Out:
# For n_clusters = 6 , the inertia is : 9.2632930050632e+19
#       index  danger level for tourists
# 0         0                          2
# 1         1                          2
# 2         2                          2
# 3         3                          2
# 4         4                          2
# ...     ...                        ...
# 2381   2381                          1
# 2382   2382                          1
# 2383   2383                          1
# 2384   2384                          1
# 2385   2385                          1
#
# [2386 rows x 2 columns]

# %%
a = list(predictions['danger level for tourists'].unique())
a
# Out:
# [2, 0, 1, 5, 3, 4]

# %% [markdown]
# ### SpectralClustering

# %%
# %%time
from sklearn.cluster import SpectralClustering
spectral_cluster_model= SpectralClustering(
    n_clusters=6,
    random_state=25,
    n_neighbors=8,
    affinity='nearest_neighbors'
)
cluster_labels = spectral_cluster_model.fit_predict(df_test)
# inertia
inertia = clusterer.inertia_
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_spectral_embedding.py:261: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   "Graph is not fully connected, spectral embedding may not work as expected."
# CPU times: user 2.86 s, sys: 2.17 s, total: 5.03 s
# Wall time: 2.62 s

# %%
print("For n_clusters =", n_clusters,
      ", the inertia is :", inertia)
# Выводим предсказания
predictions = pd.DataFrame(cluster_labels, columns=['danger level for tourists'])
predictions = predictions.reset_index()
predictions
# Out:
# For n_clusters = 6 , the inertia is : 9.2632930050632e+19
#       index  danger level for tourists
# 0         0                          0
# 1         1                          1
# 2         2                          1
# 3         3                          1
# 4         4                          1
# ...     ...                        ...
# 2381   2381                          0
# 2382   2382                          0
# 2383   2383                          0
# 2384   2384                          0
# 2385   2385                          0
#
# [2386 rows x 2 columns]

# %%
a = list(predictions['danger level for tourists'].unique())
a
# Out:
# [0, 1, 2, 4, 3, 5]
